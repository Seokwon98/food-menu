# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
menu = pd.read_csv('/content/drive/MyDrive/음식 추천 프로젝트/food_menu.csv')
info = pd.read_csv('/content/drive/MyDrive/음식 추천 프로젝트/food_crawling.csv')

# %%
menu
# Out:
#       메뉴명
# 0     고구마
# 1      갈비
# 2      보쌈
# 3     빈대떡
# 4     햄버거
# ..    ...
# 340    백숙
# 341    탕국
# 342  콩나물국
# 343  치킨가스
# 344    닭죽
#
# [345 rows x 1 columns]

# %%
info
# Out:
#                                                      0
# 0    고구마(sweet potato)는 메꽃과의 여러해살이풀로, 식품 또는 작물로서 가리...
# 1    척추동물의 허파를 감싸고 있는 빗살 모양의 갈비뼈(늑골)가 위치한 부분.\n  자세...
# 2    돼지고기나 기타 고기를 삶은 수육과 양념속을 소금에 절인 배추잎 또는 겉절이에 싸먹...
# 3    한국의 부침 요리. 기본적으로 녹두를 간 것을 베이스로, 나물이나 고기 등을 섞어서...
# 4    ▲ SBS '모닝와이드' 中\n🍔 / Hamburger\n\n패티를 구운 후 다양한...
# ..                                                 ...
# 340  백숙(白熟)이란 원래 고기나 생선 등을 물에 넣고 끓인 요리를 총칭한다. 현대에 와...
# 341  제사상에 올리는 국. 탕수, 탕수국이라고도 부른다.\n\n쇠고기, 두부, 깍뚝썰기한...
# 342  한국 요리 중의 하나. 국의 종류로 콩나물이 들어간 국을 말한다. 한국에서는 숙취 ...
# 343  돈가스의 닭고기 버전으로, 돼지고기가 아닌 닭고기살을 저며서 빵가루 옷을 입히고 튀...
# 344  닭으로 백숙을 해먹고 남은 국물과 고기를 잘게 찢어서 찹쌀[1]을 넣고 끓여만든 죽...
#
# [345 rows x 1 columns]

# %%
info.columns = ['content']
info
# Out:
#                                                content
# 0    고구마(sweet potato)는 메꽃과의 여러해살이풀로, 식품 또는 작물로서 가리...
# 1    척추동물의 허파를 감싸고 있는 빗살 모양의 갈비뼈(늑골)가 위치한 부분.\n  자세...
# 2    돼지고기나 기타 고기를 삶은 수육과 양념속을 소금에 절인 배추잎 또는 겉절이에 싸먹...
# 3    한국의 부침 요리. 기본적으로 녹두를 간 것을 베이스로, 나물이나 고기 등을 섞어서...
# 4    ▲ SBS '모닝와이드' 中\n🍔 / Hamburger\n\n패티를 구운 후 다양한...
# ..                                                 ...
# 340  백숙(白熟)이란 원래 고기나 생선 등을 물에 넣고 끓인 요리를 총칭한다. 현대에 와...
# 341  제사상에 올리는 국. 탕수, 탕수국이라고도 부른다.\n\n쇠고기, 두부, 깍뚝썰기한...
# 342  한국 요리 중의 하나. 국의 종류로 콩나물이 들어간 국을 말한다. 한국에서는 숙취 ...
# 343  돈가스의 닭고기 버전으로, 돼지고기가 아닌 닭고기살을 저며서 빵가루 옷을 입히고 튀...
# 344  닭으로 백숙을 해먹고 남은 국물과 고기를 잘게 찢어서 찹쌀[1]을 넣고 끓여만든 죽...
#
# [345 rows x 1 columns]

# %%
menu['index'] = menu.index
info['index'] = info.index

# %%
df = pd.merge(menu,info)
df
# Out:
#       메뉴명  index                                            content
# 0     고구마      0  고구마(sweet potato)는 메꽃과의 여러해살이풀로, 식품 또는 작물로서 가리...
# 1      갈비      1  척추동물의 허파를 감싸고 있는 빗살 모양의 갈비뼈(늑골)가 위치한 부분.\n  자세...
# 2      보쌈      2  돼지고기나 기타 고기를 삶은 수육과 양념속을 소금에 절인 배추잎 또는 겉절이에 싸먹...
# 3     빈대떡      3  한국의 부침 요리. 기본적으로 녹두를 간 것을 베이스로, 나물이나 고기 등을 섞어서...
# 4     햄버거      4  ▲ SBS '모닝와이드' 中\n🍔 / Hamburger\n\n패티를 구운 후 다양한...
# ..    ...    ...                                                ...
# 340    백숙    340  백숙(白熟)이란 원래 고기나 생선 등을 물에 넣고 끓인 요리를 총칭한다. 현대에 와...
# 341    탕국    341  제사상에 올리는 국. 탕수, 탕수국이라고도 부른다.\n\n쇠고기, 두부, 깍뚝썰기한...
# 342  콩나물국    342  한국 요리 중의 하나. 국의 종류로 콩나물이 들어간 국을 말한다. 한국에서는 숙취 ...
# 343  치킨가스    343  돈가스의 닭고기 버전으로, 돼지고기가 아닌 닭고기살을 저며서 빵가루 옷을 입히고 튀...
# 344    닭죽    344  닭으로 백숙을 해먹고 남은 국물과 고기를 잘게 찢어서 찹쌀[1]을 넣고 끓여만든 죽...
#
# [345 rows x 3 columns]

# %%
df = df.drop(df.columns[[1]], axis=1)
df
# Out:
#       메뉴명                                            content
# 0     고구마  고구마(sweet potato)는 메꽃과의 여러해살이풀로, 식품 또는 작물로서 가리...
# 1      갈비  척추동물의 허파를 감싸고 있는 빗살 모양의 갈비뼈(늑골)가 위치한 부분.\n  자세...
# 2      보쌈  돼지고기나 기타 고기를 삶은 수육과 양념속을 소금에 절인 배추잎 또는 겉절이에 싸먹...
# 3     빈대떡  한국의 부침 요리. 기본적으로 녹두를 간 것을 베이스로, 나물이나 고기 등을 섞어서...
# 4     햄버거  ▲ SBS '모닝와이드' 中\n🍔 / Hamburger\n\n패티를 구운 후 다양한...
# ..    ...                                                ...
# 340    백숙  백숙(白熟)이란 원래 고기나 생선 등을 물에 넣고 끓인 요리를 총칭한다. 현대에 와...
# 341    탕국  제사상에 올리는 국. 탕수, 탕수국이라고도 부른다.\n\n쇠고기, 두부, 깍뚝썰기한...
# 342  콩나물국  한국 요리 중의 하나. 국의 종류로 콩나물이 들어간 국을 말한다. 한국에서는 숙취 ...
# 343  치킨가스  돈가스의 닭고기 버전으로, 돼지고기가 아닌 닭고기살을 저며서 빵가루 옷을 입히고 튀...
# 344    닭죽  닭으로 백숙을 해먹고 남은 국물과 고기를 잘게 찢어서 찹쌀[1]을 넣고 끓여만든 죽...
#
# [345 rows x 2 columns]

# %%
df = df.rename(columns={'메뉴명':'menu'})

# %%
df['content'].replace(r'\s+|\\n', ' ', regex=True, inplace=True)

# %%
df
# Out:
#      menu                                            content
# 0     고구마  고구마(sweet potato)는 메꽃과의 여러해살이풀로, 식품 또는 작물로서 가리...
# 1      갈비  척추동물의 허파를 감싸고 있는 빗살 모양의 갈비뼈(늑골)가 위치한 부분. 자세한 내...
# 2      보쌈  돼지고기나 기타 고기를 삶은 수육과 양념속을 소금에 절인 배추잎 또는 겉절이에 싸먹...
# 3     빈대떡  한국의 부침 요리. 기본적으로 녹두를 간 것을 베이스로, 나물이나 고기 등을 섞어서...
# 4     햄버거  ▲ SBS '모닝와이드' 中 🍔 / Hamburger 패티를 구운 후 다양한 부재료...
# ..    ...                                                ...
# 340    백숙  백숙(白熟)이란 원래 고기나 생선 등을 물에 넣고 끓인 요리를 총칭한다. 현대에 와...
# 341    탕국  제사상에 올리는 국. 탕수, 탕수국이라고도 부른다. 쇠고기, 두부, 깍뚝썰기한 무 ...
# 342  콩나물국  한국 요리 중의 하나. 국의 종류로 콩나물이 들어간 국을 말한다. 한국에서는 숙취 ...
# 343  치킨가스  돈가스의 닭고기 버전으로, 돼지고기가 아닌 닭고기살을 저며서 빵가루 옷을 입히고 튀...
# 344    닭죽  닭으로 백숙을 해먹고 남은 국물과 고기를 잘게 찢어서 찹쌀[1]을 넣고 끓여만든 죽...
#
# [345 rows x 2 columns]

# %%
#df['content'].replace(r"[^가-힣]", "",regex=True, inplace=True)
df['content'].replace(r"[^가-힣\.\s]", "",regex=True, inplace=True)

# %%
df
# Out:
#      menu                                            content
# 0     고구마  고구마 는 메꽃과의 여러해살이풀로 식품 또는 작물로서 가리킬 때는 특히 전분이 발달...
# 1      갈비  척추동물의 허파를 감싸고 있는 빗살 모양의 갈비뼈늑골가 위치한 부분. 자세한 내용은...
# 2      보쌈  돼지고기나 기타 고기를 삶은 수육과 양념속을 소금에 절인 배추잎 또는 겉절이에 싸먹...
# 3     빈대떡  한국의 부침 요리. 기본적으로 녹두를 간 것을 베이스로 나물이나 고기 등을 섞어서 ...
# 4     햄버거    모닝와이드     패티를 구운 후 다양한 부재료와 함께 빵 사이에 끼워 먹는 음...
# ..    ...                                                ...
# 340    백숙  백숙이란 원래 고기나 생선 등을 물에 넣고 끓인 요리를 총칭한다. 현대에 와서는 주...
# 341    탕국  제사상에 올리는 국. 탕수 탕수국이라고도 부른다. 쇠고기 두부 깍뚝썰기한 무 또는 ...
# 342  콩나물국  한국 요리 중의 하나. 국의 종류로 콩나물이 들어간 국을 말한다. 한국에서는 숙취 ...
# 343  치킨가스  돈가스의 닭고기 버전으로 돼지고기가 아닌 닭고기살을 저며서 빵가루 옷을 입히고 튀겨...
# 344    닭죽  닭으로 백숙을 해먹고 남은 국물과 고기를 잘게 찢어서 찹쌀을 넣고 끓여만든 죽. 생...
#
# [345 rows x 2 columns]

# %%
df.to_csv('크롤링데이터.csv',index=False)

# %%
#print(df.loc[[23,24,25]])
# Out:
#     menu                                            content
# 23    커피                    아 커피는 얼마나 달콤한가 천 번의 키스보다 사랑스...
# 24     전   자세한 내용은 전한국 요리 문서를 참고하십시오 자세한 내용은 전화폐 문서를 참고하...
# 25  삼각김밥  삼각김밥은 오니기리 주먹밥의 대표적인 형태로 밥을 삼각형 모양으로 빚어 김으로 감싼...

# %%
df.isnull().sum()
# Out:
# menu        0
# content    28
# dtype: int64
